# %% [markdown]
# # 0. 주제
# # 코로나와 대기 오염의 상관관계를 알아보자
#
# # 1. 프로젝트 목표 및 내용
#  국내의 코로나 진행 상황과 대기 오염에 관한 정보를 수집, 분석하여 이들의 관계를 알아본다. 이 프로젝트에서는 세 종류의 데이터를 수집한다. 먼저 대한민국 코로나 확진자 수를 통해 국내 감염 진행 상황을 확인한다. 두번째로 대중교통 이용 상황을 통해 실제 사람들이 얼마나 활동하는지를 확인한다. 마지막으로 일평균 대기환경 정보를 통해 대기 오염의 정도를 측정한다. 이 세가지 정보를 정리하고 분석함으로써 코로나가 우리 생활에 얼마나 영향을 끼쳤는지, 그것이 다시 대기 오염에 어떤 영향을 미쳤는지 알아볼것이다.
#
#
# # 2. 주제 선정 이유 또는 이 프로젝트의 중요성
#  최근 인터넷에서 흥미로운 기사가 올라온다. 신종 코로나바이러스 감염증으로 인해 멕시코의 어느 해안에 인적이 끊기자 60년만에 발광 플랑크톤이 다시 나타났다는 것이다. 또한 코로나 사태를 지나며 중국에서 발생한 이산화질소의 양이 급격히 감소했다는 기사도 있었다. 이런 기사를 보며 코로나와 환경 사이에 어느 관계가 있음을 짐작할 수 있다.
#
#  그리고, 인간의 활동은 환경에 부정적인 영향을 끼친다고 알려져 있다. 하지만 인간의 활동이 줄어드는 것이 환경에 긍정적인가에 대해서는 일상생활에서 알기 힘들다. 보통 인간의 활동을 이유없이 제한할 수 없기 때문이다. 하지만 이번 코로나19라는 특수한 상황은 우리의 사회활동을 현저하게 감소시켰다. 따라서 지금 상황은 인간의 활동과 환경오염의 관계에 알아볼 수 있는 기회라고 할 수 있다. 이런 이유로 웹/파이썬 프로그래밍을 통해 코로나와 대기 오염의 관계를 알아보고자 한다.
#
#  프로그램 작성 전에는 코로나19로 인해 대기 오염이 줄어들었을 것이라 추측한다. 우리가 상식적으로 알 듯이 인간의 활동 증가로 대기 오염이 심화된 것이라면, 반대로 대기오염이 완화되면 인간의 활동이 줄은 것이라 할 수 있기 때문이다. 이 둘은 어느정도 비례관계가 있을 거라 생각한다.
#
#
# # 3. 데이터 획득
# 세 종류의 데이터를 수집한다. 첫번째로 공공 데이터 포탈에서 대한민국 내의 코로나 확진자 데이터를 수집한다. 두번째로 서울 열린데이터 광장의 서울시 기간별 일평균 대기환경 정보를 얻는다. 세번째로 동일한 곳에서 일별 대중교통 이용현황을 수집한다. 데이터를 수집하는데는 python과 requests을 사용한다.
#
# **코로나 확진자 수 데이터**
#
# coronaboard.kr에서 cvs파일 : https://github.com/jooeungen/coronaboard_kr
#
# **기간별 일평균 대기환경 정보**
#
# 서울시 일별 평균 대기오염도 정보 : http://data.seoul.go.kr/dataList/OA-2218/S/1/datasetView.do
#
# **일별 대중교통 이용현황**
#
# 서울시 버스노선별 정류장별 승하차 인원 정보 : http://data.seoul.go.kr/dataList/OA-12912/S/1/datasetView.do<br>
# 서울시 지하철호선별 역별 승하차 인원 정보 : http://data.seoul.go.kr/dataList/OA-12914/S/1/datasetView.do
#
# **인증키**
#
# 서울시 인증키 : 64654e6c6d73696d3130396f49524671<br>
# //공공데이터 인증키 : a6ydtglWjhngePAVbAr%2BfUIFqFtBJ2sRkwionLn5IeoQhgmOVru6W7if2Sp6gypd7aksEk%2BtekTsleanviv8Ew%3D%3D<br>
#
#
# # 4. 구현 내용 설명
# 데이터 수집 -> 데이터 가공 -> 그래프 작성 -> 데이터 분석 순으로 진행한다.
#
# **데이터 수집 및 가공**
#
# 우리가 알고 싶은 것은 코로나의 진행 상황에 따라 사람들의 활동과 환경오염이 어떻게 변해가는지이다. 따라서 각 데이터를 일별로 꺽은 선 그래프를 그릴 수 있게 가공한다.
#
# - 코로나 확진자 수 데이터
#
# coronaboard.kr에서 cvs파일을 받아 읽는다. 2020년 1월 21일부터의 확진자, 사망자, 완치자, 검사수, 음성판정수 데이터가 있다. cvs를 읽는 방법은 파이썬 강의에서 쓴 cvs모듈을 이용한다. 파일을 읽은 뒤 날짜를 받고 해당 날짜의 코로나 확진자 수를 반환하는 함수를 만든다.
#
# - 서울시 일별 평균 대기오염도 정보
#
# 이곳은 날짜별로 50개 지역의 NO2, O3, CO, SO2, PM10 PM25정보가 들어온다. 원하는 시작 날짜, 끝 날짜, 수집할 데이터 종류를 입력하면 그래프를 그려주는 함수를 만든다.
#
# - 서울시 버스 노선별 정류장별 승하차 인원 정보
#
# 날짜별로 38773개의 승하차 데이터가 있다. 사용일자, 노선ID, 노선번호, 정류장ID, 역ID, 승차총승객수, 하차총승객수 등 여러 데이터가 있지만 데이터를 단순화하기 위해 날짜별 승차승객수의 총합만을 사용할 것이다. 데이터의 수가 상당히 많기 때문에 처음 일부 데이터만을 수집, 이용할 것이다.
#
# **그래프 그리기**
#
# 코로나가 본격적으로 진행되기 전인 2월 1일부터 시간이 지난 6월 1일 까지의 데이터를 모으고, matplotlib를 이용해 각각 데이터를 날짜에 따라 꺽은선 그래프로 그린다. 제작의 편의상 데이터 수집, 가공, 그래프 그리기를 한 함수 안에 작성한다.
#
# **함수**
#
# **GetHtmlFromInternet(url) -> str**
#
# url의 html을 읽어 str로 반환
#
# **GetSeoulUrl(dataType, startIndex, endIndex, yeaer, month, date) -> str**
#
# 서울 열린 데이터 광장에 접근하는 url을 반환. 이때 서울시 인증키는 함수 밖에 전역으로 만들어져있어야 함
#
# **Date2Date(dateStr) -> int**
#
# 문자열형식의 날짜를 2020년 1월 1일을 기준으로 일 수로 바꾸어 반환한다. "20200107"- > 7
#
# **GetNextDate(str) -> str**
#
# 문자열형식 날짜의 다음날을 문자열로 반환한다. 이때 2020년은 윤년이니 2월은 29일까지 센다. "20200103" -> "20200104"
#
# **ProcessCoronaData(startDate, endDate, dataType)**
#
# 시작일~끝일까지의 코로나 데이터의 그래프를 그린다.<br>
# 여기서 dataType은 그래프를 그리고 싶은 데이터의 종류<br>
# dateType : 0:confirmed, 1:death, 2:released, 3:candidate, 4:negative
#
# **ProcessCoronaDataDay(startDate, endDate, dataType)**
#
# ProcessCoronaData와 비슷하지만 그래프를 일별 변화량으로 그린다.
#
# **ProcessAirQualityData(startDate, endDate, dataType)**
#
# 시작일~끝일까지의 대기오염정도의 그래프를 그린다.<br>
# 여기서 dataType은 그래프를 그리고 싶은 데이터의 종류<br>
# dataType: 'no2', 'o3', 'co', 'so2', 'pm10', 'pm25'
#
# **ProcessBus(startDate, endDate)**
#
# 시작일~끝일까지의 서울시의 일부 버스 탑승객 그래프를 그린다.<br>
#
# **ProcessSubway(startDate, endDate)**
#
# 시작일~끝일까지의 서울시의 지하철 탑승객 그래프를 그린다.
#
#
# # 5. 분석 결과 또는 구현 결과
# 모든 데이터는 2020년 2월 1일 부터 6월 1일까지 수집하였다.
#
# **코로나 총 감염자 수**
# ![Corona_sum.png](attachment:Corona_sum.png)
# **코로나 일일 감염자 수**
# ![Corona_day.png](attachment:Corona_day.png)
# **대기 오염 정보 일산화탄소(ppm)**
# ![Air_co.png](attachment:Air_co.png)
# **대기 오염 정보 이산화질소(ppm)**
# ![Air_no2.png](attachment:Air_no2.png)
# **대기 오염 정보 오존(ppm)**
# ![Air_o3.png](attachment:Air_o3.png)
# **대기 오염 정보 아황산가스(ppm)**
# ![Air_so2.png](attachment:Air_so2.png)
# **대기 오염 정보 미세먼지(ug/m^2)**
# ![Air_pm10.png](attachment:Air_pm10.png)
# **대기 오염 정보 초미세먼지(ug/m^2)**
# ![Air_pm25.png](attachment:Air_pm25.png)
# **일일 버스 탑승객**
# ![Bus.png](attachment:Bus.png)
# **일일 지하철 탑승객**
# ![Subway.png](attachment:Subway.png)
#
# # 6. 결론
#
#  코로나 감염자, 대기오염, 대중교통 이용 상황을 정리해보았다. 실제로 코로나가 대기오염에 영향을 끼쳤을까? 눈으로 보기에 영향을 주었다 하면 그렇지 않다. 데이터를 보면 일산화탄소, 이산화질소와 초미세먼지는 아주 조금이나마 감소한 것 같지만, 아황산가스와 미세먼지는 불규칙적이고 오존은 오히려 상승하였다. 환경은 하나가 아닌 여러가지 요인이 복합적으로 작용한다는 점이 문제였다. 예를 들어 여름에는 자외선이 강해져 대기중 오존농도가 자연스래 상승한다. 우리가 그래프를 그린다 하여도 이것이 정말 코로나의 영향인지 알 수 없다는 점을 간과하였다.
#
#  하지만 조사과정에서 코로나가 우리의 활동을 정말로 감소시켰다는 것을 알 수 있었다. 그래프를 보면 2월 1일을 기준으로 하여 코로나 확진자가 가장 큰 30일정도를 전후로 대중교통 이용이 급감하였고, 이후 사태가 안정됨에 따라 이용자 수가 회복하는 것을 볼 수 있다. 그리고 이용자 수가 이전 수준으로 회복이 되어가자 사람들의 인식이 무뎌지고 이태원발 코로나가 터져 확진자 수가 다시 증가한 것도 볼 수 있다.
#
#  마지막으로 다시 말하면 코로나는 우리 생활에 분명한 영향을 끼쳤지만 그것이 환경에 영향을 끼쳤는지는 알 수 없었다. 이를 알기 위해서는 환경에 영향을 주는 많은 요인들과 더 광범위한 데이터 조사가 필요하다. 이러한 것들이 전문적으로 이루어 졌을 때서야 둘 사이의 관계에 대해 알 수 있다고 말할 수 있을 것이다.
#
#
# # 7. 오픈소스 활용한 부분 명시
# python와 matplotlib, BeautifulSoup 모듈을 사용하였다. 오픈소스인지는 모르겠다.,
#
# # 8. 참고문헌
# Term_Project_2020<br>
# Step_13_File 강의<br>
# https://medium.com/@whj2013123218/%EC%98%A4%ED%94%88-api%EB%A5%BC-%ED%86%B5%ED%95%9C-%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%88%98%EC%A7%91-e1dd0ad203b6
#
# # 9. 획득 데이터 원본
#
# 코로나 확진자 수 정보:<br>
# kr_daily.csv 파일<br>
# 대기오염 정보 (끝 세부분에 /시작인덱스/끝인덱스/날짜):<br>
# http://openAPI.seoul.go.kr:8088/64654e6c6d73696d3130396f49524671/xml/DailyAverageAirQuality/1/40/20200201<br>
# 버스 탑승객 정보:<br>
# http://openAPI.seoul.go.kr:8088/64654e6c6d73696d3130396f49524671/xml/CardBusStatisticsServiceNew/1/100/20200201<br>
# 지하철 탑승객 정보:<br>
# http://openAPI.seoul.go.kr:8088/64654e6c6d73696d3130396f49524671/xml/CardSubwayStatsNew/1/100/20200201<br>
#
#
# # 10. 프로젝트를 위해 본인이 직접 개발한 python 소스코드 원본

# %%
import requests
from matplotlib import pyplot as plt
from bs4 import BeautifulSoup

seoulOpenDataKey = "64654e6c6d73696d3130396f49524671"

def GetHtmlFromInternet(url):
    """(str) -> str
    해당 url의 html을 str로 반환합니다.
    """
    req = requests.get(url)
    html = req.text
    return html

def GetSeoulUrl(dataType, startIndex, endIndex, date):
    """(str, int, int, int, int, int) -> str
    서울열린데이터 광장에 접근할 수 있는 url을 만듭니다.
    >>> GetSeoulUrl("DailyAverageAirQuality", 1, 5, "20200420")
    """
    url = "http://openAPI.seoul.go.kr:8088/" + seoulOpenDataKey + "/xml/"
    url +=  dataType + "/{0}/{1}/".format(startIndex, endIndex) + date
    return url

def Date2Date(dateStr):
    """
    문자열 date를 2020년 1월 1일 부터의 날짜로 환산하여 반환한다.
    """
    month = int(dateStr[4:6])
    date = int(dateStr[6:8])
    if month == 1:
        date += 0
    elif month == 2:
        date += 31
    elif month == 3:
        date += 60
    elif month == 4:
        date += 91
    elif month == 5:
        date += 121
    elif month == 6:
        date += 152
    elif month == 7:
        date += 182
    elif month == 8:
        date += 213
    elif month == 9:
        date += 244
    elif month == 10:
        date += 274
    elif month == 11:
        date += 305
    elif month == 12:
        date += 335
    return date
    

def GetNextDate(str):
    """
    문자열날짜를 넣으면 다음 날짜를 내보낸다. 2020년 기준으로 작성
    >>> GetNextDate("20200101")
    20200102
    """
    year = int(str[0:4])
    month = int(str[4:6])
    date = int(str[6:8])
    
    date += 1
    
    if (month==2 and date==30):
        month += 1
        date = 1
    elif ((month==1 or month==3 or month==5 or month==7 or month==8 or month==10 or month==12) and date==32):
        month += 1
        date = 1
    elif ((month==4 or month==6 or month==9 or month==11) and date==31):
        month += 1
        date = 1
        
    return "{0:04d}".format(year) + "{0:02d}".format(month) + "{0:02d}".format(date)

def ProcessCoronaData(startDate, endDate, dataType):
    """
    dateRange : 20200121 ~ 20200613
    dateType : 0:confirmed, 1:death, 2:released, 3:candidate, 4:negative
    """
    x = []
    y = []
    fileDictionary = {}
    fileTemp = []

    # csv파일로 부터 데이터를 받는다.
    # 이때 날짜를 넣으면 데이터리스트를 받는 딕셔너리 형태로 만든다.
    with open("kr_daily.csv") as fileRead:
        for lineContent in fileRead:
            fileTemp = lineContent.strip('\n').split(',')
            fileDictionary[fileTemp[0]] = fileTemp[1:]

    # dataType에 맞는 그래프를 그린다.
    curDate = startDate
    while (curDate != endDate):
        x.append(Date2Date(curDate) - Date2Date("20200201"))
        y.append(int(fileDictionary[curDate][dataType]))

        curDate = GetNextDate(curDate)

    plt.plot(x, y)
    plt.title("Corona Confimed Case")
    plt.show()

    return


def ProcessCoronaDataDay(startDate, endDate, dataType):
    """
    dateRange : 20200121 ~ 20200613
    dateType : 0:confirmed, 1:death, 2:released, 3:candidate, 4:negative
    """
    before = 0
    x = []
    y = []
    fileDictionary = {}
    fileTemp = []

    # csv파일로 부터 데이터를 받는다.
    # 이때 날짜를 넣으면 데이터리스트를 받는 딕셔너리 형태로 만든다.
    with open("kr_daily.csv") as fileRead:
        for lineContent in fileRead:
            fileTemp = lineContent.strip('\n').split(',')
            fileDictionary[fileTemp[0]] = fileTemp[1:]

    # dataType에 맞는 그래프를 그린다.
    curDate = startDate
    while (curDate != endDate):
        x.append(Date2Date(curDate) - Date2Date("20200201"))
        y.append(int(fileDictionary[curDate][dataType]) - before)
        before = int(fileDictionary[curDate][dataType])
        curDate = GetNextDate(curDate)

    plt.plot(x, y)
    plt.title("Corona Confimed Case")
    plt.show()

    return


def ProcessAirQualityData(startDate, endDate, dataType):
    """
    공기 그래프를 그린다. 시작부터 끝까지
    dataType: 'no2', 'o3', 'co', 'so2', 'pm10', 'pm25'
    """
    sum = 0.0

    x = []
    y = []
    
    curDate = startDate
    while (curDate != endDate) :
        sum = 0.0

        #온라인으로 데이터를 받는다.
        url = GetSeoulUrl("DailyAverageAirQuality", 1, 40, curDate)

        print("Read :", url)
        
        req = requests.get(url)
        html = req.text
        soup = BeautifulSoup(html, 'html.parser')
        
        all_data = soup.find_all(dataType)

        # 데이터가 있을 경우 데이터를 더하고 없으면 건너뛴다.
        for data in all_data:
            if (data.text != ""):
                sum += float(data.text)
            else:
                continue

        # 40으로 나눠 평균값을 구하고 그래프에 추가한다.
        x.append(Date2Date(curDate) - Date2Date("20200201"))
        y.append(sum / 40)
        
        curDate = GetNextDate(curDate)

    plt.plot(x, y)
    plt.title("Seoul Qir Quality Data (" + dataType + ")")
    plt.show()

    return


def ProcessBus(startDate, endDate):
    """
    서울시 버스 탑승객의 날짜별 그래프를 그린다.
    데이터가 너무 많기 때문에 처음 100개 정류장만을 수집한다.
    """
    x = []
    y = []
    
    curDate = startDate
    while (curDate != endDate) :
        sum = 0

        #온라인으로 데이터를 받는다. 100개만
        url = GetSeoulUrl("CardBusStatisticsServiceNew", 1, 100, curDate)

        print("READ :", url)
            
        req = requests.get(url)
        html = req.text
        soup = BeautifulSoup(html, 'html.parser')
        all_data = soup.find_all('ride_pasgr_num')

        # 데이터가 있을 경우 데이터를 더하고 없으면 건너뛴다.
        for data in all_data:
            if (data.text != ""):
                sum += int(data.text)
            else:
                continue

        # 평균 데이터를 그래프에 추가한다.
        x.append(Date2Date(curDate) - Date2Date("20200201"))
        y.append(sum / 100)
        
        curDate = GetNextDate(curDate)

    plt.plot(x, y)
    plt.title("Seoul Bus Ride Passenger")
    plt.show()

    return

def ProcessSubway(startDate, endDate):
    """
    지하철 탑승객의 날짜별 그래프를 그린다.
    데이터가 너무 많기 때문에 처음 100개 데이터만을 수집한다.
    """
    x = []
    y = []
    
    curDate = startDate
    while (curDate != endDate) :
        sum = 0

        #온라인으로 데이터를 받는다. 100개만
        url = GetSeoulUrl("CardSubwayStatsNew", 1, 100, curDate)

        print("READ :", url)
            
        req = requests.get(url)
        html = req.text
        soup = BeautifulSoup(html, 'html.parser')
        all_data = soup.find_all('ride_pasgr_num')

        # 데이터가 있을 경우 데이터를 더하고 없으면 건너뛴다.
        for data in all_data:
            if (data.text != ""):
                sum += int(data.text)
            else:
                continue

        # 평균 데이터를 그래프에 추가한다.
        x.append(Date2Date(curDate) - Date2Date("20200201"))
        y.append(sum / 100)
        
        curDate = GetNextDate(curDate)

    plt.plot(x, y)
    plt.title("Seoul Subway Ride Passenger")
    plt.show()

    return


# 수집할 날짜는 "20200201" ~ "20200601"

ProcessCoronaData("20200201", "20200601", 0)
ProcessCoronaDataDay("20200201", "20200601", 0)
ProcessAirQualityData("20200201", "20200601", 'no2')
ProcessAirQualityData("20200201", "20200601", 'o3')
ProcessAirQualityData("20200201", "20200601", 'co')
ProcessAirQualityData("20200201", "20200601", 'so2')
ProcessAirQualityData("20200201", "20200601", 'pm10')
ProcessAirQualityData("20200201", "20200601", 'pm25')
ProcessBus("20200201", "20200601")
ProcessSubway("20200201", "20200601")
